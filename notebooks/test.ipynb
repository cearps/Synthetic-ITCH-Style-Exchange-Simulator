# %%
from qrsdp_reader import read_header, read_day

hdr = read_header("../output/test_ts_930/2026-01-02.qrsdp")
print(f"market_open_ns = {hdr['market_open_ns']}")  # Should be 34200000000000

events = read_day("../output/test_ts_930/2026-01-02.qrsdp")
print(f"first ts_ns = {events['ts_ns'][0]}")   # Should be ~34.2 trillion
print(f"last  ts_ns = {events['ts_ns'][-1]}")  # Should be < 34260 billion (60s session)
# Out:
# market_open_ns = 34200000000000
# first ts_ns = 34200003510394
# last  ts_ns = 34259992431001
